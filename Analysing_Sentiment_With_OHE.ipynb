# %% [markdown]
# # Analysing Sentiment

# %% [markdown]
# ## Setup

# %%
# !pip install textblob

# %%
import tensorflow as tf
import tensorflow.python.keras.backend as K
import numpy as np
import pandas as pd
import random
import os
import multiprocessing
import warnings
import nltk


TRACE = False

# %%
print(tf.__version__)
# Out:
# 2.14.0

# %%
def set_seeds_and_trace():
  os.environ["PYTHONHASHSEED"] = '0'
  np.random.seed(42)
  tf.random.set_seed(42)
  random.seed(42)
  if TRACE:
    tf.debugging.get_log_device_placement(True)

def set_sessions_with_gpus_and_cores():
  cores = multiprocessing.cpu_count()
  gpus = len(tf.config.list_physical_devices("GPU"))
  config = tf.compat.v1.ConfigProto(device_count={ "GPU": gpus, "CPU": cores }, intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
  sess = tf.compat.v1.Session(config=config)
  K.set_session(sess)


set_seeds_and_trace()
set_sessions_with_gpus_and_cores()
warnings.filterwarnings("ignore")
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# %%writefile get_data.sh
# if [ ! -f yelp.csv ]; then
#   wget -O yelp.csv https://www.dropbox.com/s/xds4lua69b7okw8/yelp.csv?dl=0
# fi
# Out:
# Writing get_data.sh

# %%
# !bash get_data.sh
# Out:
# --2023-12-05 10:31:53--  https://www.dropbox.com/s/xds4lua69b7okw8/yelp.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/xds4lua69b7okw8/yelp.csv [following]
# --2023-12-05 10:31:53--  https://www.dropbox.com/s/raw/xds4lua69b7okw8/yelp.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc83549dad0ec357e25acc2d5020.dl.dropboxusercontent.com/cd/0/inline/CI1pgz-zG6vFDWeu0aA29OsuurS-mTW2fiuhjsz7QxdY6mqrXo2LgKAgD8alRHVPldBQKMUZXRr9Oal-zj6L8F-_IAgy8SvhDdwuRr6cWa7huSXsvXfzeQ1sFo4dw_3TguBOuiLHcuBuhIfmAiRG2s3j/file# [following]
# ...

# %%
yelp = pd.read_csv('yelp.csv')
yelp.head(10)
# Out:
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
# 5  -yxfBYGB6SEqszmxJxd97A  2007-12-13  m2CKSsepBCoRYWxiRUsxAg      4
# 6  zp713qNhx8d9KCJJnrw1xA  2010-02-12  riFQ3vxNpP4rWLk_CSri2A      5
# 7  hW0Ne_HTHEAgGF1rAdmR-g  2012-07-12  JL7GXJ9u4YMx7Rzs05NfiQ      4
# 8  wNUea3IXZWD63bbOQaOH-g  2012-08-17  XtnfnYmnJYi71yIuGsXIUA      4
# 9  nMHhuYan8e3cONo3PornJA  2010-08-11  jJAIXA46pU1swYyRCdfXtQ      5
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# ...

# %%
yelp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   business_id  10000 non-null  object
#  1   date         10000 non-null  object
#  2   review_id    10000 non-null  object
#  3   stars        10000 non-null  int64
#  4   text         10000 non-null  object
#  5   type         10000 non-null  object
#  6   user_id      10000 non-null  object
#  7   cool         10000 non-null  int64
#  8   useful       10000 non-null  int64
#  9   funny        10000 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 781.4+ KB

# %% [markdown]
# We will cosider 5 and 4 star as positive and 3, 2, and 1 as negetive review. and negetive review is 0 and positive review is 1

# %%
# Create a new dataframe with postive and negetive review
yelp_df = yelp.copy()
yelp_df['stars'] = yelp_df['stars'].apply(lambda x: 0 if x < 4 else 1)
# Out:
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      1
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      1
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      1
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      1
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      1
# 5  -yxfBYGB6SEqszmxJxd97A  2007-12-13  m2CKSsepBCoRYWxiRUsxAg      1
# 6  zp713qNhx8d9KCJJnrw1xA  2010-02-12  riFQ3vxNpP4rWLk_CSri2A      1
# 7  hW0Ne_HTHEAgGF1rAdmR-g  2012-07-12  JL7GXJ9u4YMx7Rzs05NfiQ      1
# 8  wNUea3IXZWD63bbOQaOH-g  2012-08-17  XtnfnYmnJYi71yIuGsXIUA      1
# 9  nMHhuYan8e3cONo3PornJA  2010-08-11  jJAIXA46pU1swYyRCdfXtQ      1
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# ...

# %%
X = yelp_df.text
y = yelp_df.stars

# %%
y.value_counts()
# Out:
# 1    6863
# 0    3137
# Name: stars, dtype: int64

# %% [markdown]
# There is more positive reviews than negetive.
